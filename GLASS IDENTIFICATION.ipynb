# %% [markdown]
# # Glass Identification

# %% [markdown]
# Project Description
# The dataset describes the chemical properties of glass and involves classifying samples of glass using their chemical properties as one of six classes. The dataset was credited to Vina Spiehler in 1987. The study of classification of types of glass was motivated by criminological investigation. At the scene of the crime, the glass left can be used as evidence...if it is correctly identified!
#
# The chemical compositions are measured as the weight percent in corresponding oxide.
# Attribute Information-
# 1.	 Id number: 1 to 214
# 2.	 RI: refractive index
# 3.	Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
# 4.	Mg: Magnesium
# 5.	Al: Aluminum
# 6.	Si: Silicon
# 7.	K: Potassium
# 8.	Ca: Calcium
# 9.	Ba: Barium
# 10.	Fe: Iron
# 11.	Type of glass: (class attribute)
# •	1- building_windows_float_processed
# •	2- building_windows_non_float_processed
# •	3- vehicle_windows_float_processed
# •	4- vehicle_windows_non_float_processed (none in this database)
# •	5- containers
# •	6- tableware
# •	7- headlamps
# There are 214 observations in the dataset. The dataset can be divided into window glass (classes 1-4) and non-window glass (classes 5-7).
# Predict : Type of glass
#
# Dataset Link-
# •	https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv
# •	https://github.com/dsrscientist/dataset3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
df=pd.read_csv(r'C:\Users\Cape-Mumbai\Downloads\raw.githubusercontent.com_p-sama_Glass-Classification_master_glass.csv')
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.shape
# Out:
# (214, 10)

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']

# %%
# Checking the null values
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# As we will see there are no null values in the dataset

# %%
# Visualize using Heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# And we clearly visualize that there are no null values

# %%
#Checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI, Length: 178, dtype: int64
#
#
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Na, Length: 142, dtype: int64
#
#
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg, Length: 94, dtype: int64
#
#
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: Al, Length: 118, dtype: int64
#
#
# 72.86    4
# 72.99    4
# 73.10    4
# 73.28    4
# 73.11    4
#         ..
# 73.55    1
# 72.34    1
# 72.26    1
# 73.26    1
# 73.61    1
# Name: Si, Length: 133, dtype: int64
#
#
# 0.00    30
# 0.57    12
# 0.56    11
# 0.60    11
# 0.58    10
# ...

# %% [markdown]
# Now, we can see ther are no missing values or blank values in the dataset

# %%
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="float":
        numerical_col.append(i)
print("Numerical Columns:",numerical_col)
# Out:
# Numerical Columns: ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe']

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %% [markdown]
# As per my observation:
#
# There is a big gap between 75% and max values of Potassium There is a big gap between 75% and max values of Calcium column.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Univaraite Analysis

# %%
ax=sns.countplot(x='Type',data=df)
print(df['Type'].value_counts())
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %% [markdown]
# We see that Type 2 and 1 have the highest occurences in the dataset, so we need to make sure that the train and test dataset have a good representation from all the types.This indicates an imbalance which will need to be rectified so that our machine learning model do not get biased to a certain value during prediction.

# %%
#Visualize the count of Mg
print(df['Mg'].value_counts())
ax=sns.countplot(x='Mg',data=df)
plt.show()
# Out:
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg, Length: 94, dtype: int64

# %%
#Visualize the count of Al
print(df['Al'].value_counts())
ax=sns.countplot(x='Al',data=df)
plt.show()
# Out:
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: Al, Length: 118, dtype: int64

# %%
#Visualize the count of K
print(df['K'].value_counts())
ax=sns.countplot(x='K',data=df)
plt.show()
# Out:
# 0.00    30
# 0.57    12
# 0.56    11
# 0.60    11
# 0.58    10
#         ..
# 0.44     1
# 0.07     1
# 0.73     1
# 0.70     1
# 1.41     1
# Name: K, Length: 65, dtype: int64

# %%
#Visualize the count of K
print(df['Ca'].value_counts())
ax=sns.countplot(x='Ca',data=df)
plt.show()
# Out:
# 8.03    5
# 8.43    5
# 9.57    4
# 8.79    4
# 8.44    4
#        ..
# 9.23    1
# 8.90    1
# 9.13    1
# 8.09    1
# 8.62    1
# Name: Ca, Length: 143, dtype: int64

# %%
#Let's check the data has been distributed in each column
plt.figure(figsize=(10,5),facecolor="white")
plotnumber=1
for col in numerical_col:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[col],color="m")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# We can see the skewness in every column except Mg

# %% [markdown]
# Bivarate Analysis

# %%
#Comparing Type and Mg
plt.title("Comparison between Type and Mg")
sns.barplot(x="Type",y="Mg",data=df)
plt.show()

# %%
#Comparing Type and Al
plt.title("Comparison between Type and Al")
sns.barplot(x="Type",y="Al",data=df)
plt.show()

# %%
#Comparing Type and Ca
plt.title("Comparison between Type and Ca")
sns.barplot(x="Type",y="Ca",data=df)
plt.show()

# %%
#Comparing Type and K
plt.title("Comparison between Type and K")
sns.barplot(x="Type",y="K",data=df)
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
sns.pairplot(df,hue="Type",palette="Dark2")
plt.show()

# %% [markdown]
# There are no outliers in any of the columns.

# %% [markdown]
# # Checking for Outliers

# %%
df.shape
# Out:
# (214, 10)

# %%
plt.figure(figsize=(10,6),facecolor="white")
plotnumber=1
for col in numerical_col:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[col],palette="Set2_r")
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# All columns contains outliers, so we need to remove the outliers through Z Score method

# %%
import scipy.stats as stats
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)

df=df[(z<3).all(axis=1)]
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 208  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.0     7
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
#
# [194 rows x 10 columns]

# %%
df.shape
# Out:
# (194, 10)

# %%
data_loss=(214-194)/214*100
data_loss
# Out:
# 9.345794392523365

# %% [markdown]
# After removing the outliers we are checking the data loss percentage by comparing the rows in our original data set and the new data set post removal of the outliers.

# %%
df.skew()
# Out:
# RI      0.952733
# Na      0.371482
# Mg     -1.528849
# Al      0.658259
# Si     -0.425450
# K       0.303175
# Ca      1.077962
# Ba      3.188587
# Fe      1.486479
# Type    1.284007
# dtype: float64

# %%
df['Mg']=np.cbrt(df['Mg'])
df['Si']=np.cbrt(df['Si'])
df['Ba']=np.cbrt(df['Ba'])

# %%
df.skew()
# Out:
# RI      0.952733
# Na      0.371482
# Mg     -1.899050
# Al      0.658259
# Si     -0.447904
# K       0.303175
# Ca      1.077962
# Ba      2.207594
# Fe      1.486479
# Type    1.284007
# dtype: float64

# %%
df.corr()
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000  0.050760  0.063399 -0.522197 -0.610107 -0.368238  0.690650
# Na    0.050760  1.000000 -0.526123  0.253127 -0.235596 -0.612183  0.019987
# Mg    0.063399 -0.526123  1.000000 -0.580115 -0.361350  0.494707 -0.400040
# Al   -0.522197  0.253127 -0.580115  1.000000  0.335819  0.005827 -0.213304
# Si   -0.610107 -0.235596 -0.361350  0.335819  1.000000  0.073788 -0.166827
# K    -0.368238 -0.612183  0.494707  0.005827  0.073788  1.000000 -0.500579
# Ca    0.690650  0.019987 -0.400040 -0.213304 -0.166827 -0.500579  1.000000
# Ba   -0.226018  0.547500 -0.651379  0.599309  0.182935 -0.294253 -0.140398
# Fe   -0.020046 -0.209838  0.150666 -0.117764  0.023507  0.099394 -0.011635
# Type -0.167355  0.533025 -0.782430  0.660262  0.261617 -0.383499  0.154762
#
#             Ba        Fe      Type
# RI   -0.226018 -0.020046 -0.167355
# Na    0.547500 -0.209838  0.533025
# Mg   -0.651379  0.150666 -0.782430
# ...

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel('Features_name',fontsize=14)
plt.title('Descriptive Graph',fontsize=20)
plt.show()

# %%
df.corr()
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000  0.050760  0.063399 -0.522197 -0.610107 -0.368238  0.690650
# Na    0.050760  1.000000 -0.526123  0.253127 -0.235596 -0.612183  0.019987
# Mg    0.063399 -0.526123  1.000000 -0.580115 -0.361350  0.494707 -0.400040
# Al   -0.522197  0.253127 -0.580115  1.000000  0.335819  0.005827 -0.213304
# Si   -0.610107 -0.235596 -0.361350  0.335819  1.000000  0.073788 -0.166827
# K    -0.368238 -0.612183  0.494707  0.005827  0.073788  1.000000 -0.500579
# Ca    0.690650  0.019987 -0.400040 -0.213304 -0.166827 -0.500579  1.000000
# Ba   -0.226018  0.547500 -0.651379  0.599309  0.182935 -0.294253 -0.140398
# Fe   -0.020046 -0.209838  0.150666 -0.117764  0.023507  0.099394 -0.011635
# Type -0.167355  0.533025 -0.782430  0.660262  0.261617 -0.383499  0.154762
#
#             Ba        Fe      Type
# RI   -0.226018 -0.020046 -0.167355
# Na    0.547500 -0.209838  0.533025
# Mg   -0.651379  0.150666 -0.782430
# ...

# %%
import matplotlib.pyplot as plt

from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
X = df.drop('Type', axis=1)
Y = df['Type']

# %%
Y.value_counts()
# Out:
# 1    70
# 2    68
# 7    23
# 3    16
# 5     9
# 6     8
# Name: Type, dtype: int64

# %% [markdown]
# Listing the values of our label column to count the number of rows occupied by each category. This indicates class imbalance that we will need to fix by using the oversampling method.

# %%
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 1    70
# 2    70
# 3    70
# 5    70
# 6    70
# 7    70
# Name: Type, dtype: int64

# %% [markdown]
# After applying over sampling we are one again listing the values of our label column to cross verify the updated information. Here we see that we have successfully resolved the class imbalance problem and now all the categories have same data ensuring that the machine learning model does not get biased towards one category.

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 415    7
# 416    7
# 417    7
# 418    7
# 419    7
# Name: Type, Length: 420, dtype: int64

# %%
X
# Out:
#            RI         Na        Mg        Al        Si         K        Ca  \
# 0    1.521010  13.640000  1.649740  1.100000  4.155926  0.060000  8.750000
# 1    1.517610  13.890000  1.532619  1.360000  4.174180  0.480000  7.830000
# 2    1.516180  13.530000  1.525490  1.540000  4.179148  0.390000  7.780000
# 3    1.517660  13.210000  1.545286  1.290000  4.171883  0.570000  8.220000
# 4    1.517420  13.270000  1.535452  1.240000  4.180865  0.550000  8.070000
# ..        ...        ...       ...       ...       ...       ...       ...
# 415  1.515583  13.879194  0.000000  2.551578  4.183321  0.137957  9.402168
# 416  1.516543  14.787218  0.000000  2.363258  4.184676  0.000000  8.839524
# 417  1.518287  14.708252  0.000000  2.001344  4.183076  0.000000  8.415125
# 418  1.520865  13.488237  1.490709  1.341910  4.169063  0.823820  8.173977
# 419  1.518250  14.485678  0.000000  1.994864  4.185785  0.000000  8.490271
#
#            Ba        Fe
# 0    0.000000  0.000000
# ...

# %% [markdown]
# SCALING

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    1.292156  0.069757  0.995639 -0.981671 -1.925840 -0.930617 -0.438922
# 1   -0.284956  0.399932  0.814408 -0.403186 -0.103698  0.505139 -1.175144
# 2   -0.948271 -0.075520  0.803378 -0.002696  0.392226  0.197477 -1.215156
# 3   -0.261763 -0.498145  0.834009 -0.558932 -0.332984  0.812801 -0.863050
# 4   -0.373089 -0.418903  0.818792 -0.670179  0.563617  0.744432 -0.983086
# ..        ...       ...       ...       ...       ...       ...       ...
# 415 -1.225279  0.385661 -1.557136  2.248005  0.808710 -0.664124  0.082971
# 416 -0.779804  1.584889 -1.557136  1.829005  0.943984 -1.135725 -0.367281
# 417  0.029012  1.480599 -1.557136  1.023767  0.784286 -1.135725 -0.706903
# 418  1.225126 -0.130677  0.749558 -0.443436 -0.614519  1.680476 -0.899880
# 419  0.011702  1.186646 -1.557136  1.009351  1.054714 -1.135725 -0.646767
#
#            Ba        Fe
# 0   -0.474276 -0.488259
# 1   -0.474276 -0.488259
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)

# %%
# Classification Model Function

def classify(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)
    
    # Training the model
    model.fit(X_train, Y_train)
    
    # Predicting Y_test
    pred = model.predict(X_test)
    
    # Accuracy Score
    acc_score = (accuracy_score(Y_test, pred))*100
    print("Accuracy Score:", acc_score)
    
    # Classification Report
    class_report = classification_report(Y_test, pred)
    print("\nClassification Report:\n", class_report)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of accuracy minus cv scores
    result = acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is", result)

# %%
# Logistic Regression

model=LogisticRegression()
classify(model, X, Y)
# Out:
# Accuracy Score: 83.33333333333334
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.73      0.69      0.71        16
#            2       0.56      0.36      0.43        14
#            3       0.80      1.00      0.89        12
#            5       1.00      1.00      1.00        12
#            6       0.93      1.00      0.96        13
#            7       0.89      1.00      0.94        17
#
#     accuracy                           0.83        84
#    macro avg       0.82      0.84      0.82        84
# weighted avg       0.81      0.83      0.82        84
#
# Cross Validation Score: 83.0952380952381
#
# Accuracy Score - Cross Validation Score is 0.2380952380952408

# %%
# Support Vector Classifier

model=SVC(C=1.0, kernel='rbf', gamma='auto', random_state=42)
classify(model, X, Y)
# Out:
# Accuracy Score: 86.90476190476191
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.69      0.73        16
#            2       0.64      0.64      0.64        14
#            3       0.85      0.92      0.88        12
#            5       1.00      1.00      1.00        12
#            6       0.93      1.00      0.96        13
#            7       1.00      1.00      1.00        17
#
#     accuracy                           0.87        84
#    macro avg       0.87      0.87      0.87        84
# weighted avg       0.87      0.87      0.87        84
#
# Cross Validation Score: 85.47619047619047
#
# Accuracy Score - Cross Validation Score is 1.4285714285714448

# %%
# Decision Tree Classifier

model=DecisionTreeClassifier(random_state=21, max_depth=15)
classify(model, X, Y)
# Out:
# Accuracy Score: 80.95238095238095
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.60      0.56      0.58        16
#            2       0.57      0.57      0.57        14
#            3       0.90      0.75      0.82        12
#            5       1.00      1.00      1.00        12
#            6       0.93      1.00      0.96        13
#            7       0.89      1.00      0.94        17
#
#     accuracy                           0.81        84
#    macro avg       0.82      0.81      0.81        84
# weighted avg       0.81      0.81      0.81        84
#
# Cross Validation Score: 84.04761904761904
#
# Accuracy Score - Cross Validation Score is -3.095238095238088

# %%
# Random Forest Classifier

model=RandomForestClassifier(max_depth=15, random_state=111)
classify(model, X, Y)
# Out:
# Accuracy Score: 94.04761904761905
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.83      0.94      0.88        16
#            2       0.92      0.86      0.89        14
#            3       1.00      0.83      0.91        12
#            5       1.00      1.00      1.00        12
#            6       0.93      1.00      0.96        13
#            7       1.00      1.00      1.00        17
#
#     accuracy                           0.94        84
#    macro avg       0.95      0.94      0.94        84
# weighted avg       0.94      0.94      0.94        84
#
# Cross Validation Score: 86.66666666666669
#
# Accuracy Score - Cross Validation Score is 7.380952380952365

# %%
# K Neighbors Classifier

model=KNeighborsClassifier(n_neighbors=15)
classify(model, X, Y)
# Out:
# Accuracy Score: 82.14285714285714
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.62      0.81      0.70        16
#            2       0.86      0.43      0.57        14
#            3       0.67      0.67      0.67        12
#            5       0.92      1.00      0.96        12
#            6       0.93      1.00      0.96        13
#            7       1.00      1.00      1.00        17
#
#     accuracy                           0.82        84
#    macro avg       0.83      0.82      0.81        84
# weighted avg       0.83      0.82      0.81        84
#
# Cross Validation Score: 79.04761904761905
#
# Accuracy Score - Cross Validation Score is 3.095238095238088

# %%
# Extra Trees Classifier

model=ExtraTreesClassifier()
classify(model, X, Y)
# Out:
# Accuracy Score: 90.47619047619048
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.74      0.88      0.80        16
#            2       0.91      0.71      0.80        14
#            3       1.00      0.83      0.91        12
#            5       1.00      1.00      1.00        12
#            6       0.93      1.00      0.96        13
#            7       0.94      1.00      0.97        17
#
#     accuracy                           0.90        84
#    macro avg       0.92      0.90      0.91        84
# weighted avg       0.91      0.90      0.90        84
#
# Cross Validation Score: 88.0952380952381
#
# Accuracy Score - Cross Validation Score is 2.3809523809523796

# %%
svc_param = {'kernel' : ['poly', 'sigmoid', 'rbf'],
             'gamma' : ['scale', 'auto'],
             'shrinking' : [True, False],
             'random_state' : [21,42,104],
             'probability' : [True, False],
             'decision_function_shape' : ['ovo', 'ovr'],
             'verbose' : [True, False]}

# %%
GSCV = GridSearchCV(SVC(), svc_param, cv=5)

# %%
GSCV.fit(X_train,Y_train)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSV
# ...

# %%
GSCV.best_params_
# Out:
# {'decision_function_shape': 'ovo',
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'verbose': True}

# %%
Final_Model = SVC(decision_function_shape='ovo', gamma='scale', kernel='rbf', probability=True, random_state=21,
                 shrinking=True, verbose=True)
Classifier = Final_Model.fit(X_train, Y_train)
fmod_pred = Final_Model.predict(X_test)
fmod_acc = (accuracy_score(Y_test, fmod_pred))*100
print("Accuracy score for the Best Model is:", fmod_acc)
# Out:
# [LibSVM]Accuracy score for the Best Model is: 86.90476190476191

# %% [markdown]
# Model Perfomance

# %%
from sklearn.metrics import confusion_matrix

# %%
# Let's plot the confusion matrix
mat = confusion_matrix(Y_train, Y_Pred)
plt.subplots(figsize=(12,8))
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 2
#       1 # Let's plot the confusion matrix
# ----> 2 mat = confusion_matrix(Y_train, Y_Pred)
#       3 plt.subplots(figsize=(12,8))
#       4 sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
#
# NameError: name 'Y_Pred' is not defined

# %%
print(classification_report(Y_train, Y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 print(classification_report(Y_train, Y_pred))
#
# NameError: name 'Y_pred' is not defined
